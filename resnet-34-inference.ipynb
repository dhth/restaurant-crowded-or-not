# %%
from fastai.vision import ImageDataBunch, create_cnn, open_image, get_transforms, imagenet_stats, models, show_image
from pathlib import Path

# %% [markdown]
# `path` is where the saved model resides (inside another directory `models`)

# %%
path = Path('/home/nbuser/inf_test')

# %%
path.ls()
# Out:
# [PosixPath('/home/nbuser/inf_test/models')]

# %%
classes = ['crowded', 'empty']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('rest-saved-model1')

# %%
img = open_image('test_img1.jpg')

# %%
show_image(img,figsize=(10,8));

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'crowded'

# %%
img2 = open_image('test_img2.jpg')

# %%
show_image(img2,figsize=(10,8));

# %%
pred_class,pred_idx,outputs = learn.predict(img2)
pred_class
# Out:
# 'empty'
